# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../../../workflow_test_tolerance_snr3_10ppm_automatic_mod_selection_normalized_cscore/report_K(UniMod:1)_K(UniMod:747).tsv", delimiter="\t")

# %%
df
# Out:
#                                               File.Name  \
# 0     ../workflow_test_tolerance_snr3_10ppm_automati...
# 1     ../workflow_test_tolerance_snr3_10ppm_automati...
# 2     ../workflow_test_tolerance_snr3_10ppm_automati...
# 3     ../workflow_test_tolerance_snr3_10ppm_automati...
# 4     ../workflow_test_tolerance_snr3_10ppm_automati...
# ...                                                 ...
# 5780  ../workflow_test_tolerance_snr3_10ppm_automati...
# 5781  ../workflow_test_tolerance_snr3_10ppm_automati...
# 5782  ../workflow_test_tolerance_snr3_10ppm_automati...
# 5783  ../workflow_test_tolerance_snr3_10ppm_automati...
# 5784  ../workflow_test_tolerance_snr3_10ppm_automati...
#
#                                                  Run  \
# 0     lower_energy_windows_K(UniMod:1)_K(UniMod:747)
# 1     lower_energy_windows_K(UniMod:1)_K(UniMod:747)
# 2     lower_energy_windows_K(UniMod:1)_K(UniMod:747)
# 3     lower_energy_windows_K(UniMod:1)_K(UniMod:747)
# ...

# %%
targets_df = df[~df["Q.Value"].isna()]
decoys_df = df[df["Q.Value"].isna()]

decoys_df.loc[:, "Q.Value"] = pd.to_numeric(decoys_df["Precursor.Id"])
decoys_df.loc[:, "Precursor.Id"] = decoys_df["Modified.Sequence"]
decoys_df.loc[:, "CScore"] = decoys_df["RT.Start"]

# %%
targets_df.rename(
            columns={"CScore": "CScore_unnormalized"}, inplace=True
        )
targets_df["CScore_unnormalized"]
# Out:
# /tmp/ipykernel_3159031/946499986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targets_df.rename(
# 0       0.673589
# 1       0.586294
# 2       0.572346
# 3       0.556531
# 4       0.532417
#           ...
# 3401    0.691511
# 3402    0.533480
# 3403    0.486117
# 3404    0.571258
# 3405    0.560989
# Name: CScore_unnormalized, Length: 3406, dtype: float64

# %%
decoys_df.rename(
            columns={"CScore": "CScore_unnormalized"}, inplace=True
        )
decoys_df["CScore_unnormalized"]
